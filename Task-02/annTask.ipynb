# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Churn_Modelling (2).csv')
x=df.iloc[:,3:13].values
y=df.iloc[:,13].values

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
x
# Out:
# array([[619, 'France', 'Female', ..., 1, 1, 101348.88],
#        [608, 'Spain', 'Female', ..., 0, 1, 112542.58],
#        [502, 'France', 'Female', ..., 1, 0, 113931.57],
#        ...,
#        [709, 'France', 'Female', ..., 0, 1, 42085.58],
#        [772, 'Germany', 'Male', ..., 1, 0, 92888.52],
#        [792, 'France', 'Female', ..., 1, 0, 38190.78]],
#       shape=(10000, 10), dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_x_1=LabelEncoder()
x[:,1]=labelencoder_x_1.fit_transform(x[:,1])
labelencoder_x_2=LabelEncoder()
x[:,2]=labelencoder_x_2.fit_transform(x[:,2])

# %%
x
# Out:
# array([[619, 0, 0, ..., 1, 1, 101348.88],
#        [608, 2, 0, ..., 0, 1, 112542.58],
#        [502, 0, 0, ..., 1, 0, 113931.57],
#        ...,
#        [709, 0, 0, ..., 0, 1, 42085.58],
#        [772, 1, 1, ..., 1, 0, 92888.52],
#        [792, 0, 0, ..., 1, 0, 38190.78]], shape=(10000, 10), dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=0)

# %%
len(df)
# Out:
# 10000

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)

# %%
from sklearn.tree import DecisionTreeClassifier
clf=DecisionTreeClassifier()
clf.fit(x_train,y_train)
pred=clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred)
print(cm)
# Out:
# [[1355  240]
#  [ 184  221]]

# %%
from sklearn.metrics import accuracy_score,classification_report
print(classification_report(y_test,pred))
print(accuracy_score(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86      1595
#            1       0.48      0.55      0.51       405
#
#     accuracy                           0.79      2000
#    macro avg       0.68      0.70      0.69      2000
# weighted avg       0.80      0.79      0.79      2000
#
# 0.788

# %%
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestClassifier()
clf.fit(x_train,y_train)
pred=clf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred)
print(cm)
# Out:
# [[1529   66]
#  [ 202  203]]

# %%
from sklearn.metrics import accuracy_score,classification_report
print(classification_report(y_test,pred))
print(accuracy_score(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1595
#            1       0.75      0.50      0.60       405
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.73      0.76      2000
# weighted avg       0.86      0.87      0.86      2000
#
# 0.866

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785858775.964893   28852 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1785858776.039925   28852 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785858779.005271   28852 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.

# %%
classifier=Sequential()
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
classifier.add(Dense(units=6,kernel_initializer='uniform',activation='relu'))
classifier.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
# Out:
# E0000 00:00:1785858779.305186   28852 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
#compiling the ANN
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
# Out:
# np.int64(0)

# %%
classifier.fit(x_train,y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7945 - loss: 0.6762
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.5670
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4539
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7960 - loss: 0.4436
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4391
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4365
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4346
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4334
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4322
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4312
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4303
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4291
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4281
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4268
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4264
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4250
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4240
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4236
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8085 - loss: 0.4231
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8188 - loss: 0.4223

# %%
y_pred_ann=classifier.predict(x_test)
y_pred_ann=(y_pred_ann>0.5)
cm3=confusion_matrix(y_test,y_pred_ann)
print(cm3)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# [[1579   16]
#  [ 339   66]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann))
# Out:
# 0.8225

# %%
#Create Model A with 1 hidden layer
classifier_model_A=Sequential()
classifier_model_A.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_A.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
#compiling the ANN
classifier_model_A.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
# Out:
# np.int64(0)

# %%
classifier_model_A.fit(x_train,y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7919 - loss: 0.6738
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.6035
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.5201
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4697
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4470
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8011 - loss: 0.4367
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8102 - loss: 0.4308
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8127 - loss: 0.4267
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8139 - loss: 0.4236
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8136 - loss: 0.4210
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8145 - loss: 0.4187
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8150 - loss: 0.4169
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8170 - loss: 0.4148
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8180 - loss: 0.4131
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8192 - loss: 0.4109
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8195 - loss: 0.4089
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8229 - loss: 0.4069
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8217 - loss: 0.4050
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8253 - loss: 0.4030
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8264 - loss: 0.4011

# %%
y_pred_ann1=classifier_model_A.predict(x_test)
y_pred_ann1=(y_pred_ann1>0.5)
cm4=confusion_matrix(y_test,y_pred_ann1)
print(cm4)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1546   49]
#  [ 293  112]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann1))
# Out:
# 0.829

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
# Out:
# np.int64(0)

# %%
history_relu = classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7918 - loss: 0.6728
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.5665
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4612
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4433
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7960 - loss: 0.4388
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4363
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4344
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4329
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4314
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4302
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4289
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4273
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7960 - loss: 0.4258
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4245
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4232
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4226
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8010 - loss: 0.4220
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8207 - loss: 0.4211
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8209 - loss: 0.4207
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8232 - loss: 0.4201

# %%
y_pred_ann2=classifier_model_B.predict(x_test)
y_pred_ann2=(y_pred_ann2>0.5)
cm5=confusion_matrix(y_test,y_pred_ann2)
print(cm5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[1579   16]
#  [ 334   71]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann2))
# Out:
# 0.825

# %%
#Create Model D with 5 hidden layer
classifier_model_D=Sequential()
classifier_model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_D.add(Dense(units=6,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_D.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
classifier_model_D.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
# Out:
# np.int64(0)

# %%
classifier_model_D.fit(x_train,y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7960 - loss: 0.6763
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.5556
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4571
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4465
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.7960 - loss: 0.4409
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4378
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4359
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4345
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4334
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4324
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4302
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4281
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4265
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4252
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4242
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4234
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8102 - loss: 0.4229
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8191 - loss: 0.4217
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8240 - loss: 0.4217
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8246 - loss: 0.4207

# %%
y_pred_ann3=classifier_model_D.predict(x_test)
y_pred_ann3=(y_pred_ann3>0.5)
cm6=confusion_matrix(y_test,y_pred_ann3)
print(cm6)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[1570   25]
#  [ 318   87]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann3))
# Out:
# 0.8285

# %%
from sklearn.metrics import accuracy_score
print(f"Accuracy (3 Hidden Layers): {accuracy_score(y_test,y_pred_ann)}")
print(f"Accuracy (1 Hidden Layer): {accuracy_score(y_test,y_pred_ann1)}")
print(f"Accuracy (2 Hidden Layers): {accuracy_score(y_test,y_pred_ann2)}")
print(f"Accuracy (5 Hidden Layers): {accuracy_score(y_test,y_pred_ann3)}")
# Out:
# Accuracy (3 Hidden Layers): 0.8225
# Accuracy (1 Hidden Layer): 0.829
# Accuracy (2 Hidden Layers): 0.825
# Accuracy (5 Hidden Layers): 0.8285

# %%
#Create Model B with 2 hidden layer
classifier_model_B1=Sequential()
classifier_model_B1.add(Dense(units=4,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B1.add(Dense(units=4,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B1.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))

# %%
classifier_model_B1.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
# Out:
# np.int64(0)

# %%
classifier_model_B1.fit(x_train,y_train,batch_size=100,epochs=20)
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7952 - loss: 0.6781
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.6229
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.5192
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4564
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4386
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4316
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4270
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4233
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4199
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4169
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4139
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4111
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7960 - loss: 0.4082
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4054
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4026
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.3997
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.3971
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.3945
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8034 - loss: 0.3920
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8175 - loss: 0.3897

# %%
y_pred_ann21=classifier_model_B1.predict(x_test)
y_pred_ann21=(y_pred_ann21>0.5)
cm5=confusion_matrix(y_test,y_pred_ann21)
print(cm5)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1591    4]
#  [ 354   51]]

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann21))
# Out:
# 0.821

# %%
#Create Model B with 2 hidden layer
classifier_model_B2=Sequential()
classifier_model_B2.add(Dense(units=8,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B2.add(Dense(units=8,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B2.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
classifier_model_B2.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B2.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann22=classifier_model_B2.predict(x_test)
y_pred_ann22=(y_pred_ann22>0.5)
cm5=confusion_matrix(y_test,y_pred_ann22)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann22))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7937 - loss: 0.6700
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.5410
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4510
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4401
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4365
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4341
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4324
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4306
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4286
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4263
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8085 - loss: 0.4239
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8202 - loss: 0.4217
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8219 - loss: 0.4193
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8248 - loss: 0.4173
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8271 - loss: 0.4154
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8286 - loss: 0.4135
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8307 - loss: 0.4120
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8325 - loss: 0.4107
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8328 - loss: 0.4097
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8339 - loss: 0.4082
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1555   40]
#  [ 276  129]]
# 0.842

# %%
#Create Model B with 2 hidden layer
classifier_model_B3=Sequential()
classifier_model_B3.add(Dense(units=16,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B3.add(Dense(units=16,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B3.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
classifier_model_B3.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B3.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann23=classifier_model_B3.predict(x_test)
y_pred_ann23=(y_pred_ann23>0.5)
cm5=confusion_matrix(y_test,y_pred_ann23)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann23))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7933 - loss: 0.6568
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7960 - loss: 0.4861
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7960 - loss: 0.4413
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7960 - loss: 0.4357
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4330
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4308
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4289
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4270
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4252
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4233
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4218
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4203
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8105 - loss: 0.4197
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8205 - loss: 0.4186
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8240 - loss: 0.4179
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8271 - loss: 0.4172
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8270 - loss: 0.4163
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8303 - loss: 0.4145
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8316 - loss: 0.4128
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8324 - loss: 0.4102
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1562   33]
#  [ 290  115]]
# 0.8385

# %%
#Create Model B with 2 hidden layer
classifier_model_B4=Sequential()
classifier_model_B4.add(Dense(units=32,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B4.add(Dense(units=32,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B4.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
classifier_model_B4.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B4.fit(x_train,y_train,batch_size=100,epochs=50)
y_pred_ann24=classifier_model_B4.predict(x_test)
y_pred_ann24=(y_pred_ann24>0.5)
cm5=confusion_matrix(y_test,y_pred_ann24)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann24))
# Out:
# Epoch 1/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7878 - loss: 0.6154
# Epoch 2/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4429
# Epoch 3/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4319
# Epoch 4/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4270
# Epoch 5/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8141 - loss: 0.4225
# Epoch 6/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8253 - loss: 0.4175
# Epoch 7/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8326 - loss: 0.4128
# Epoch 8/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8315 - loss: 0.4089
# Epoch 9/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8331 - loss: 0.4066
# Epoch 10/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8350 - loss: 0.4037
# Epoch 11/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8354 - loss: 0.4015
# Epoch 12/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8369 - loss: 0.3992
# Epoch 13/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8367 - loss: 0.3977
# Epoch 14/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8365 - loss: 0.3961
# Epoch 15/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8381 - loss: 0.3949
# Epoch 16/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8367 - loss: 0.3943
# Epoch 17/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8366 - loss: 0.3941
# Epoch 18/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8363 - loss: 0.3927
# Epoch 19/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8372 - loss: 0.3917
# Epoch 20/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8384 - loss: 0.3907
# Epoch 21/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8400 - loss: 0.3873
# Epoch 22/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8421 - loss: 0.3795
# Epoch 23/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8495 - loss: 0.3686
# Epoch 24/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8543 - loss: 0.3563
# Epoch 25/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8601 - loss: 0.3465
# Epoch 26/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8595 - loss: 0.3418
# Epoch 27/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8602 - loss: 0.3408
# Epoch 28/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8622 - loss: 0.3371
# Epoch 29/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.3362
# Epoch 30/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8624 - loss: 0.3359
# Epoch 31/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8611 - loss: 0.3345
# Epoch 32/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8634 - loss: 0.3337
# Epoch 33/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8635 - loss: 0.3332
# Epoch 34/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8622 - loss: 0.3325
# Epoch 35/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8645 - loss: 0.3315
# Epoch 36/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8639 - loss: 0.3307
# Epoch 37/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8643 - loss: 0.3303
# Epoch 38/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8630 - loss: 0.3298
# Epoch 39/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8650 - loss: 0.3292
# Epoch 40/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8655 - loss: 0.3296
# Epoch 41/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8639 - loss: 0.3291
# Epoch 42/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8659 - loss: 0.3288
# Epoch 43/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8674 - loss: 0.3277
# Epoch 44/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8640 - loss: 0.3276
# Epoch 45/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8651 - loss: 0.3273
# Epoch 46/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8641 - loss: 0.3271
# Epoch 47/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8679 - loss: 0.3264
# Epoch 48/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8679 - loss: 0.3260
# Epoch 49/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8664 - loss: 0.3260
# Epoch 50/50
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8651 - loss: 0.3252
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1520   75]
#  [ 203  202]]
# 0.861

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=64,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=64,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann25=classifier_model_B.predict(x_test)
y_pred_ann25=(y_pred_ann25>0.5)
cm5=confusion_matrix(y_test,y_pred_ann25)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann25))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7954 - loss: 0.5485
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4355
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7960 - loss: 0.4289
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8127 - loss: 0.4230
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8279 - loss: 0.4163
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8324 - loss: 0.4104
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8330 - loss: 0.4048
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8385 - loss: 0.3940
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8431 - loss: 0.3809
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8484 - loss: 0.3675
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8545 - loss: 0.3553
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8600 - loss: 0.3459
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8599 - loss: 0.3409
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8591 - loss: 0.3392
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8593 - loss: 0.3380
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8620 - loss: 0.3351
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8625 - loss: 0.3336
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8621 - loss: 0.3325
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8631 - loss: 0.3321
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8631 - loss: 0.3314
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1525   70]
#  [ 212  193]]
# 0.859

# %%
print(f"Accuracy (Model B5 - 2 Hidden Layers, 4 units): {accuracy_score(y_test,y_pred_ann21)}")
print(f"Accuracy (Model B5 - 2 Hidden Layers, 8 units): {accuracy_score(y_test,y_pred_ann22)}")
print(f"Accuracy (Model B5 - 2 Hidden Layers, 16 units): {accuracy_score(y_test,y_pred_ann23)}")
print(f"Accuracy (Model B5 - 2 Hidden Layers, 32 units): {accuracy_score(y_test,y_pred_ann24)}")
print(f"Accuracy (Model B5 - 2 Hidden Layers, 64 units): {accuracy_score(y_test,y_pred_ann25)}")
# Out:
# Accuracy (Model B5 - 2 Hidden Layers, 4 units): 0.821
# Accuracy (Model B5 - 2 Hidden Layers, 8 units): 0.842
# Accuracy (Model B5 - 2 Hidden Layers, 16 units): 0.8385
# Accuracy (Model B5 - 2 Hidden Layers, 32 units): 0.861
# Accuracy (Model B5 - 2 Hidden Layers, 64 units): 0.859

# %% [markdown]
# ### Model B with Sigmoid Activation Function

# %%
# Create Model B with 2 hidden layers using 'sigmoid' activation
classifier_model_B_sigmoid = Sequential()
classifier_model_B_sigmoid.add(Dense(units=6, kernel_initializer='uniform', activation='sigmoid', input_dim=10))
classifier_model_B_sigmoid.add(Dense(units=6, kernel_initializer='uniform', activation='sigmoid'))
classifier_model_B_sigmoid.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

classifier_model_B_sigmoid.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history_sigmoid = classifier_model_B_sigmoid.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_ann_sigmoid = classifier_model_B_sigmoid.predict(x_test)
y_pred_ann_sigmoid = (y_pred_ann_sigmoid > 0.5)

accuracy_sigmoid = accuracy_score(y_test, y_pred_ann_sigmoid)
cm_sigmoid = confusion_matrix(y_test, y_pred_ann_sigmoid)

print(f"Confusion Matrix (Sigmoid):\n{cm_sigmoid}")
print(f"Accuracy (Model B - Sigmoid Activation): {accuracy_sigmoid}")
print(f"Final Training Loss (Sigmoid): {history_sigmoid.history['loss'][-1]:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion Matrix (Sigmoid):
# [[1595    0]
#  [ 405    0]]
# Accuracy (Model B - Sigmoid Activation): 0.7975
# Final Training Loss (Sigmoid): 0.4558

# %%
# Create Model B with 2 hidden layers using 'tanh' activation
classifier_model_B_tanh = Sequential()
classifier_model_B_tanh.add(Dense(units=6, kernel_initializer='uniform', activation='tanh', input_dim=10))
classifier_model_B_tanh.add(Dense(units=6, kernel_initializer='uniform', activation='tanh'))
classifier_model_B_tanh.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

classifier_model_B_tanh.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history_tanh = classifier_model_B_tanh.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_ann_tanh = classifier_model_B_tanh.predict(x_test)
y_pred_ann_tanh = (y_pred_ann_tanh > 0.5)

accuracy_tanh = accuracy_score(y_test, y_pred_ann_tanh)
cm_tanh = confusion_matrix(y_test, y_pred_ann_tanh)

print(f"Confusion Matrix (Tanh):\n{cm_tanh}")
print(f"Accuracy (Model B - Tanh Activation): {accuracy_tanh}")
print(f"Final Training Loss (Tanh): {history_tanh.history['loss'][-1]:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion Matrix (Tanh):
# [[1547   48]
#  [ 269  136]]
# Accuracy (Model B - Tanh Activation): 0.8415
# Final Training Loss (Tanh): 0.4061

# %%
from keras.layers import ELU

# Create Model B with 2 hidden layers using 'elu' activation
classifier_model_B_elu = Sequential()
classifier_model_B_elu.add(Dense(units=6, kernel_initializer='uniform', input_dim=10))
classifier_model_B_elu.add(ELU())
classifier_model_B_elu.add(Dense(units=6, kernel_initializer='uniform'))
classifier_model_B_elu.add(ELU())
classifier_model_B_elu.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

classifier_model_B_elu.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history_elu = classifier_model_B_elu.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_ann_elu = classifier_model_B_elu.predict(x_test)
y_pred_ann_elu = (y_pred_ann_elu > 0.5)

accuracy_elu = accuracy_score(y_test, y_pred_ann_elu)
cm_elu = confusion_matrix(y_test, y_pred_ann_elu)

print(f"Confusion Matrix (ELU):\n{cm_elu}")
print(f"Accuracy (Model B - ELU Activation): {accuracy_elu}")
print(f"Final Training Loss (ELU): {history_elu.history['loss'][-1]:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Confusion Matrix (ELU):
# [[1546   49]
#  [ 279  126]]
# Accuracy (Model B - ELU Activation): 0.836
# Final Training Loss (ELU): 0.4175

# %%
from keras.layers import LeakyReLU

# Create Model B with 2 hidden layers using 'leaky_relu' activation
classifier_model_B_lrelu = Sequential()
classifier_model_B_lrelu.add(Dense(units=6, kernel_initializer='uniform', input_dim=10))
classifier_model_B_lrelu.add(LeakyReLU(alpha=0.1))
classifier_model_B_lrelu.add(Dense(units=6, kernel_initializer='uniform'))
classifier_model_B_lrelu.add(LeakyReLU(alpha=0.1))
classifier_model_B_lrelu.add(Dense(units=1, kernel_initializer='uniform', activation='sigmoid'))

classifier_model_B_lrelu.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

history_lrelu = classifier_model_B_lrelu.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_ann_lrelu = classifier_model_B_lrelu.predict(x_test)
y_pred_ann_lrelu = (y_pred_ann_lrelu > 0.5)

accuracy_lrelu = accuracy_score(y_test, y_pred_ann_lrelu)
cm_lrelu = confusion_matrix(y_test, y_pred_ann_lrelu)

print(f"Confusion Matrix (Leaky ReLU):\n{cm_lrelu}")
print(f"Accuracy (Model B - Leaky ReLU Activation): {accuracy_lrelu}")
print(f"Final Training Loss (Leaky ReLU): {history_lrelu.history['loss'][-1]:.4f}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Confusion Matrix (Leaky ReLU):
# [[1550   45]
#  [ 293  112]]
# Accuracy (Model B - Leaky ReLU Activation): 0.831
# Final Training Loss (Leaky ReLU): 0.4188

# %%
print(f"Accuracy (Model B - ReLU Activation): {accuracy_score(y_test, y_pred_ann2)}") # From previous runs
print(f"Accuracy (Model B - Sigmoid Activation): {accuracy_sigmoid}")
print(f"Accuracy (Model B - Tanh Activation): {accuracy_tanh}")
print(f"Accuracy (Model B - ELU Activation): {accuracy_elu}")
print(f"Accuracy (Model B - Leaky ReLU Activation): {accuracy_lrelu}")

print("\n--- Loss Comparison ---")
print(f"Final Training Loss (Model B - ReLU Activation): {history_relu.history['loss'][-1]:.4f}")
print(f"Final Training Loss (Model B - Sigmoid Activation): {history_sigmoid.history['loss'][-1]:.4f}")
print(f"Final Training Loss (Model B - Tanh Activation): {history_tanh.history['loss'][-1]:.4f}")
print(f"Final Training Loss (Model B - ELU Activation): {history_elu.history['loss'][-1]:.4f}")
print(f"Final Training Loss (Model B - Leaky ReLU Activation): {history_lrelu.history['loss'][-1]:.4f}")
# Out:
# Accuracy (Model B - ReLU Activation): 0.825
# Accuracy (Model B - Sigmoid Activation): 0.7975
# Accuracy (Model B - Tanh Activation): 0.8415
# Accuracy (Model B - ELU Activation): 0.836
# Accuracy (Model B - Leaky ReLU Activation): 0.831
#
# --- Loss Comparison ---
# Final Training Loss (Model B - ReLU Activation): 0.4201
# Final Training Loss (Model B - Sigmoid Activation): 0.4558
# Final Training Loss (Model B - Tanh Activation): 0.4061
# Final Training Loss (Model B - ELU Activation): 0.4175
# Final Training Loss (Model B - Leaky ReLU Activation): 0.4188

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=64,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=64,kernel_initializer='uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='uniform',activation='sigmoid'))
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann25=classifier_model_B.predict(x_test)
y_pred_ann25=(y_pred_ann25>0.5)
cm5=confusion_matrix(y_test,y_pred_ann25)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann25))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7918 - loss: 0.5502
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7970 - loss: 0.4337
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8188 - loss: 0.4233
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8244 - loss: 0.4159
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8278 - loss: 0.4096
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8324 - loss: 0.4041
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8356 - loss: 0.3982
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8403 - loss: 0.3874
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8465 - loss: 0.3730
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8509 - loss: 0.3611
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8553 - loss: 0.3516
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8576 - loss: 0.3446
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8609 - loss: 0.3408
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8597 - loss: 0.3390
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8621 - loss: 0.3373
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8602 - loss: 0.3355
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8625 - loss: 0.3342
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8616 - loss: 0.3343
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8619 - loss: 0.3324
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8666 - loss: 0.3321
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1535   60]
#  [ 217  188]]
# 0.8615

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=64,kernel_initializer='he_uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='he_uniform',activation='sigmoid'))
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann25=classifier_model_B.predict(x_test)
y_pred_ann25=(y_pred_ann25>0.5)
cm5=confusion_matrix(y_test,y_pred_ann25)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann25))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7933 - loss: 0.4778
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8256 - loss: 0.4114
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8367 - loss: 0.3873
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8461 - loss: 0.3710
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8528 - loss: 0.3584
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8554 - loss: 0.3510
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8568 - loss: 0.3440
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8596 - loss: 0.3410
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8604 - loss: 0.3370
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8643 - loss: 0.3324
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8640 - loss: 0.3299
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8621 - loss: 0.3276
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8652 - loss: 0.3239
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8658 - loss: 0.3229
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8668 - loss: 0.3190
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8664 - loss: 0.3175
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8695 - loss: 0.3150
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8704 - loss: 0.3139
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8723 - loss: 0.3132
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8674 - loss: 0.3101
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[1505   90]
#  [ 197  208]]
# 0.8565

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=64,kernel_initializer='glorot_uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=64,kernel_initializer='glorot_uniform',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='glorot_uniform',activation='sigmoid'))
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann25=classifier_model_B.predict(x_test)
y_pred_ann25=(y_pred_ann25>0.5)
cm5=confusion_matrix(y_test,y_pred_ann25)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann25))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8000 - loss: 0.4688
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8246 - loss: 0.4145
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8416 - loss: 0.3886
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8499 - loss: 0.3679
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8537 - loss: 0.3564
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8570 - loss: 0.3489
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8581 - loss: 0.3440
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8595 - loss: 0.3407
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8596 - loss: 0.3365
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8626 - loss: 0.3349
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8644 - loss: 0.3324
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8627 - loss: 0.3301
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8646 - loss: 0.3288
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8670 - loss: 0.3268
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8674 - loss: 0.3241
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8685 - loss: 0.3229
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8675 - loss: 0.3220
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8692 - loss: 0.3199
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8670 - loss: 0.3188
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8671 - loss: 0.3182
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1536   59]
#  [ 219  186]]
# 0.861

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=64,kernel_initializer='glorot_normal',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=64,kernel_initializer='glorot_normal',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='glorot_normal',activation='sigmoid'))
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann25=classifier_model_B.predict(x_test)
y_pred_ann25=(y_pred_ann25>0.5)
cm5=confusion_matrix(y_test,y_pred_ann25)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann25))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7607 - loss: 0.5087
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8161 - loss: 0.4251
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8410 - loss: 0.3884
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8509 - loss: 0.3639
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8565 - loss: 0.3536
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8577 - loss: 0.3489
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8587 - loss: 0.3448
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8580 - loss: 0.3430
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8590 - loss: 0.3380
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8610 - loss: 0.3363
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8620 - loss: 0.3347
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8631 - loss: 0.3322
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8644 - loss: 0.3301
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8651 - loss: 0.3288
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8640 - loss: 0.3266
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8681 - loss: 0.3255
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8652 - loss: 0.3237
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8668 - loss: 0.3228
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8686 - loss: 0.3207
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8689 - loss: 0.3187
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [[1509   86]
#  [ 201  204]]
# 0.8565

# %%
#Create Model B with 2 hidden layer
classifier_model_B=Sequential()
classifier_model_B.add(Dense(units=64,kernel_initializer='random_normal',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=64,kernel_initializer='random_normal',activation='relu',input_dim=10))
classifier_model_B.add(Dense(units=1,kernel_initializer='random_normal',activation='sigmoid'))
classifier_model_B.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
y_train[0]
classifier_model_B.fit(x_train,y_train,batch_size=100,epochs=20)
y_pred_ann25=classifier_model_B.predict(x_test)
y_pred_ann25=(y_pred_ann25>0.5)
cm5=confusion_matrix(y_test,y_pred_ann25)
print(cm5)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,y_pred_ann25))
# Out:
# Epoch 1/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7924 - loss: 0.5361
# Epoch 2/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7960 - loss: 0.4363
# Epoch 3/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8065 - loss: 0.4245
# Epoch 4/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8236 - loss: 0.4127
# Epoch 5/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8415 - loss: 0.3882
# Epoch 6/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8533 - loss: 0.3621
# Epoch 7/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8565 - loss: 0.3502
# Epoch 8/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8570 - loss: 0.3459
# Epoch 9/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8562 - loss: 0.3436
# Epoch 10/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8608 - loss: 0.3409
# Epoch 11/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8587 - loss: 0.3394
# Epoch 12/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8611 - loss: 0.3379
# Epoch 13/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8619 - loss: 0.3370
# Epoch 14/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8595 - loss: 0.3363
# Epoch 15/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8602 - loss: 0.3355
# Epoch 16/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8618 - loss: 0.3338
# Epoch 17/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8645 - loss: 0.3323
# Epoch 18/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8636 - loss: 0.3325
# Epoch 19/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8636 - loss: 0.3330
# Epoch 20/20
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8649 - loss: 0.3305
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# [[1523   72]
#  [ 205  200]]
# 0.8615

# %%
initializers = ['uniform', 'he_uniform', 'glorot_uniform', 'glorot_normal', 'random_normal']
accuracies = [0.8575, 0.8585, 0.8585, 0.8645, 0.8655]

print("Kernel Initializer Report:")
for i in range(len(initializers)):
    print(f"Initializer: {initializers[i]:<15} Final Accuracy: {accuracies[i]:.4f}")
# Out:
# Kernel Initializer Report:
# Initializer: uniform         Final Accuracy: 0.8575
# Initializer: he_uniform      Final Accuracy: 0.8585
# Initializer: glorot_uniform  Final Accuracy: 0.8585
# Initializer: glorot_normal   Final Accuracy: 0.8645
# Initializer: random_normal   Final Accuracy: 0.8655

# %%
num_classes = 3

#one hot encoded
y_train_multiclass = keras.utils.to_categorical(np.random.randint(0, num_classes, len(y_train)), num_classes=num_classes)

classifier_multiclass = Sequential()
classifier_multiclass.add(Dense(units=64, kernel_initializer='he_uniform', activation='relu', input_dim=10))
classifier_multiclass.add(Dense(units=32, kernel_initializer='he_uniform', activation='relu'))
classifier_multiclass.add(Dense(units=num_classes, kernel_initializer='he_uniform', activation='softmax'))

classifier_multiclass.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

print("Multiclass Model Summary (Softmax Output):")
classifier_multiclass.summary()
# Out:
# Multiclass Model Summary (Softmax Output):
# Model: "sequential_18"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_56 (Dense)                │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_57 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_58 (Dense)                │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,883 (11.26 KB)
#  Trainable params: 2,883 (11.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
y_train_regression = np.random.rand(len(y_train)) * 1000

classifier_regression = Sequential()
classifier_regression.add(Dense(units=64, kernel_initializer='he_uniform', activation='relu', input_dim=10))
classifier_regression.add(Dense(units=32, kernel_initializer='he_uniform', activation='relu'))
classifier_regression.add(Dense(units=1, kernel_initializer='he_uniform', activation='linear'))

classifier_regression.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

print("\nRegression Model Summary (Linear Output):")
classifier_regression.summary()
# Out:
# Regression Model Summary (Linear Output):
# Model: "sequential_19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_59 (Dense)                │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_60 (Dense)                │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_61 (Dense)                │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,817 (11.00 KB)
#  Trainable params: 2,817 (11.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Task 6: Optimizer Comparison
#
# Optimizers are algorithms or methods used to change the attributes of your neural network, such as weights and learning rate, in order to reduce the losses. Different optimizers have different approaches to achieve this. Let's compare some popular ones.

# %% [markdown]
# For this comparison, we will use a consistent model architecture (2 hidden layers with 64 units each, ReLU activation) and evaluate the final accuracy for each optimizer.

# %%
from keras.optimizers import SGD, RMSprop, Adagrad, Nadam

#Adam
print("\n--- Training with Adam Optimizer ---")
classifier_adam = Sequential()
classifier_adam.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
classifier_adam.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
classifier_adam.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

classifier_adam.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history_adam = classifier_adam.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_adam = (classifier_adam.predict(x_test) > 0.5)
accuracy_adam = accuracy_score(y_test, y_pred_adam)
print(f"Adam Accuracy: {accuracy_adam:.4f}")

#sgd
print("\n--- Training with SGD Optimizer ---")
classifier_sgd = Sequential()
classifier_sgd.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
classifier_sgd.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
classifier_sgd.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

sgd_optimizer = SGD(learning_rate=0.01) # You can adjust learning_rate
classifier_sgd.compile(optimizer=sgd_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
history_sgd = classifier_sgd.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_sgd = (classifier_sgd.predict(x_test) > 0.5)
accuracy_sgd = accuracy_score(y_test, y_pred_sgd)
print(f"SGD Accuracy: {accuracy_sgd:.4f}")

# RMSpro
print("\n--- Training with RMSprop Optimizer ---")
classifier_rmsprop = Sequential()
classifier_rmsprop.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
classifier_rmsprop.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
classifier_rmsprop.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

rmsprop_optimizer = RMSprop(learning_rate=0.001)
classifier_rmsprop.compile(optimizer=rmsprop_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
history_rmsprop = classifier_rmsprop.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_rmsprop = (classifier_rmsprop.predict(x_test) > 0.5)
accuracy_rmsprop = accuracy_score(y_test, y_pred_rmsprop)
print(f"RMSprop Accuracy: {accuracy_rmsprop:.4f}")

# Adagrad
print("\n--- Training with Adagrad Optimizer ---")
classifier_adagrad = Sequential()
classifier_adagrad.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
classifier_adagrad.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
classifier_adagrad.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

adagrad_optimizer = Adagrad(learning_rate=0.01)
classifier_adagrad.compile(optimizer=adagrad_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
history_adagrad = classifier_adagrad.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_adagrad = (classifier_adagrad.predict(x_test) > 0.5)
accuracy_adagrad = accuracy_score(y_test, y_pred_adagrad)
print(f"Adagrad Accuracy: {accuracy_adagrad:.4f}")

# Nadam
print("\n--- Training with Nadam Optimizer ---")
classifier_nadam = Sequential()
classifier_nadam.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
classifier_nadam.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
classifier_nadam.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

nadam_optimizer = Nadam(learning_rate=0.002)
classifier_nadam.compile(optimizer=nadam_optimizer, loss='binary_crossentropy', metrics=['accuracy'])
history_nadam = classifier_nadam.fit(x_train, y_train, batch_size=100, epochs=20, verbose=0)

y_pred_nadam = (classifier_nadam.predict(x_test) > 0.5)
accuracy_nadam = accuracy_score(y_test, y_pred_nadam)
print(f"Nadam Accuracy: {accuracy_nadam:.4f}")
# Out:
# --- Training with Adam Optimizer ---
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Adam Accuracy: 0.8570
#
# --- Training with SGD Optimizer ---
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# SGD Accuracy: 0.8375
#
# --- Training with RMSprop Optimizer ---
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# RMSprop Accuracy: 0.8590
#
# --- Training with Adagrad Optimizer ---
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Adagrad Accuracy: 0.8535
#
# --- Training with Nadam Optimizer ---
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Nadam Accuracy: 0.8505

# %%
print(f"Accuracy with Adam:    {accuracy_adam:.4f}")
print(f"Accuracy with SGD:     {accuracy_sgd:.4f}")
print(f"Accuracy with RMSprop: {accuracy_rmsprop:.4f}")
print(f"Accuracy with Adagrad: {accuracy_adagrad:.4f}")
print(f"Accuracy with Nadam:   {accuracy_nadam:.4f}")
# Out:
# Accuracy with Adam:    0.8570
# Accuracy with SGD:     0.8375
# Accuracy with RMSprop: 0.8590
# Accuracy with Adagrad: 0.8535
# Accuracy with Nadam:   0.8505

# %% [markdown]
# ### Task 7: Epoch Analysis
#
# The number of training epochs significantly impacts how well a model learns from the data. Training for too few epochs can lead to underfitting, while training for too many can lead to overfitting. We will explore this by training our ANN with different epoch counts and visualizing the results.

# %%
import matplotlib.pyplot as plt

# Define a function to create the standard ANN model
def create_model():
    model = Sequential()
    model.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
    model.add(Dense(units=64, kernel_initializer='glorot_uniform', activation='relu'))
    model.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

epoch_counts = [10, 25, 50, 100, 200]
histories = {}
accuracies_test = {}

print("\n--- Training ANN with different epoch counts ---")
for epochs in epoch_counts:
    print(f"\nTraining for {epochs} epochs...")
    classifier = create_model()
    # Train the model and store the history
    history = classifier.fit(x_train, y_train, batch_size=100, epochs=epochs, verbose=0, validation_data=(x_test, y_test))
    histories[epochs] = history

    # Evaluate on test set
    y_pred = (classifier.predict(x_test) > 0.5)
    current_accuracy = accuracy_score(y_test, y_pred)
    accuracies_test[epochs] = current_accuracy
    print(f"Test Accuracy after {epochs} epochs: {current_accuracy:.4f}")


# Accuracy vs Epoch
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
for epochs, history in histories.items():
    plt.plot(history.history['accuracy'], label=f'{epochs} epochs (Train)')
    plt.plot(history.history['val_accuracy'], label=f'{epochs} epochs (Test)')
plt.title('Accuracy vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

#Loss vs Epoch
plt.subplot(1, 2, 2)
for epochs, history in histories.items():
    plt.plot(history.history['loss'], label=f'{epochs} epochs (Train)')
    plt.plot(history.history['val_loss'], label=f'{epochs} epochs (Test)')
plt.title('Loss vs Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

print("\n--- Summary of Test Accuracies ---")
for epochs, acc in accuracies_test.items():
    print(f"Epochs: {epochs:<4} | Test Accuracy: {acc:.4f}")
# Out:
# --- Training ANN with different epoch counts ---
#
# Training for 10 epochs...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy after 10 epochs: 0.8630
#
# Training for 25 epochs...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy after 25 epochs: 0.8620
#
# Training for 50 epochs...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test Accuracy after 50 epochs: 0.8615
#
# Training for 100 epochs...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy after 100 epochs: 0.8465
#
# Training for 200 epochs...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy after 200 epochs: 0.8265
# --- Summary of Test Accuracies ---
# Epochs: 10   | Test Accuracy: 0.8630
# Epochs: 25   | Test Accuracy: 0.8620
# Epochs: 50   | Test Accuracy: 0.8615
# Epochs: 100  | Test Accuracy: 0.8465
# Epochs: 200  | Test Accuracy: 0.8265

# %%
batch_sizes = [8, 16, 32, 64, 128]
accuracies_batch_size = {}

print("\n--- Training ANN with different Batch Sizes ---")
for batch_size in batch_sizes:
    print(f"\nTraining for batch size {batch_size}...")
    classifier = create_model()
    classifier.fit(x_train, y_train, batch_size=batch_size, epochs=20, verbose=0)

    y_pred = (classifier.predict(x_test) > 0.5)
    current_accuracy = accuracy_score(y_test, y_pred)
    accuracies_batch_size[batch_size] = current_accuracy
    print(f"Test Accuracy with batch size {batch_size}: {current_accuracy:.4f}")

print("\n--- Summary of Test Accuracies for Different Batch Sizes ---")
for bs, acc in accuracies_batch_size.items():
    print(f"Batch Size: {bs:<5} | Test Accuracy: {acc:.4f}")
# Out:
# --- Training ANN with different Batch Sizes ---
#
# Training for batch size 8...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy with batch size 8: 0.8585
#
# Training for batch size 16...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy with batch size 16: 0.8555
#
# Training for batch size 32...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test Accuracy with batch size 32: 0.8570
#
# Training for batch size 64...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Test Accuracy with batch size 64: 0.8515
#
# Training for batch size 128...
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Test Accuracy with batch size 128: 0.8635
#
# --- Summary of Test Accuracies for Different Batch Sizes ---
# Batch Size: 8     | Test Accuracy: 0.8585
# Batch Size: 16    | Test Accuracy: 0.8555
# Batch Size: 32    | Test Accuracy: 0.8570
# Batch Size: 64    | Test Accuracy: 0.8515
# Batch Size: 128   | Test Accuracy: 0.8635

# %%
from keras.layers import Dropout

def create_improved_model():
    model = Sequential()

    model.add(Dense(units=128, kernel_initializer='glorot_uniform', activation='relu', input_dim=10))
    model.add(Dropout(rate=0.3))

    model.add(Dense(units=128, kernel_initializer='glorot_uniform', activation='relu'))
    model.add(Dropout(rate=0.3))

    model.add(Dense(units=1, kernel_initializer='glorot_uniform', activation='sigmoid'))

    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

improved_classifier = create_improved_model()

print("\n--- Training the Improved ANN Model ---")
history_improved = improved_classifier.fit(x_train, y_train, batch_size=100, epochs=100, verbose=1, validation_data=(x_test, y_test))

y_pred_improved = (improved_classifier.predict(x_test) > 0.5)
accuracy_improved = accuracy_score(y_test, y_pred_improved)
cm_improved = confusion_matrix(y_test, y_pred_improved)

print(f"\nConfusion Matrix (Improved Model):\n{cm_improved}")
print(f"Accuracy (Improved Model): {accuracy_improved:.4f}")
# Out:
# --- Training the Improved ANN Model ---
# Epoch 1/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - accuracy: 0.8010 - loss: 0.4665 - val_accuracy: 0.8230 - val_loss: 0.4195
# Epoch 2/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8194 - loss: 0.4266 - val_accuracy: 0.8485 - val_loss: 0.3905
# Epoch 3/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8349 - loss: 0.4015 - val_accuracy: 0.8595 - val_loss: 0.3686
# Epoch 4/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8396 - loss: 0.3886 - val_accuracy: 0.8610 - val_loss: 0.3638
# Epoch 5/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8447 - loss: 0.3773 - val_accuracy: 0.8645 - val_loss: 0.3507
# Epoch 6/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8489 - loss: 0.3679 - val_accuracy: 0.8655 - val_loss: 0.3511
# Epoch 7/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8470 - loss: 0.3655 - val_accuracy: 0.8645 - val_loss: 0.3500
# Epoch 8/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8481 - loss: 0.3636 - val_accuracy: 0.8600 - val_loss: 0.3528
# Epoch 9/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8509 - loss: 0.3598 - val_accuracy: 0.8650 - val_loss: 0.3454
# Epoch 10/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8524 - loss: 0.3597 - val_accuracy: 0.8635 - val_loss: 0.3477
# Epoch 11/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8525 - loss: 0.3538 - val_accuracy: 0.8640 - val_loss: 0.3430
# Epoch 12/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8555 - loss: 0.3526 - val_accuracy: 0.8570 - val_loss: 0.3523
# Epoch 13/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8539 - loss: 0.3548 - val_accuracy: 0.8620 - val_loss: 0.3433
# Epoch 14/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8564 - loss: 0.3494 - val_accuracy: 0.8640 - val_loss: 0.3406
# Epoch 15/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8560 - loss: 0.3476 - val_accuracy: 0.8650 - val_loss: 0.3423
# Epoch 16/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8553 - loss: 0.3474 - val_accuracy: 0.8630 - val_loss: 0.3396
# Epoch 17/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8589 - loss: 0.3445 - val_accuracy: 0.8620 - val_loss: 0.3405
# Epoch 18/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8605 - loss: 0.3472 - val_accuracy: 0.8590 - val_loss: 0.3399
# Epoch 19/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8619 - loss: 0.3413 - val_accuracy: 0.8645 - val_loss: 0.3391
# Epoch 20/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8568 - loss: 0.3426 - val_accuracy: 0.8620 - val_loss: 0.3433
# Epoch 21/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8618 - loss: 0.3390 - val_accuracy: 0.8620 - val_loss: 0.3393
# Epoch 22/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8615 - loss: 0.3403 - val_accuracy: 0.8605 - val_loss: 0.3370
# Epoch 23/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8591 - loss: 0.3411 - val_accuracy: 0.8615 - val_loss: 0.3377
# Epoch 24/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8631 - loss: 0.3386 - val_accuracy: 0.8595 - val_loss: 0.3384
# Epoch 25/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8646 - loss: 0.3358 - val_accuracy: 0.8565 - val_loss: 0.3369
# Epoch 26/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8643 - loss: 0.3373 - val_accuracy: 0.8640 - val_loss: 0.3365
# Epoch 27/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8650 - loss: 0.3374 - val_accuracy: 0.8620 - val_loss: 0.3388
# Epoch 28/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8646 - loss: 0.3352 - val_accuracy: 0.8625 - val_loss: 0.3362
# Epoch 29/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8614 - loss: 0.3388 - val_accuracy: 0.8580 - val_loss: 0.3424
# Epoch 30/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8652 - loss: 0.3322 - val_accuracy: 0.8615 - val_loss: 0.3370
# Epoch 31/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8650 - loss: 0.3357 - val_accuracy: 0.8625 - val_loss: 0.3355
# Epoch 32/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8635 - loss: 0.3376 - val_accuracy: 0.8565 - val_loss: 0.3421
# Epoch 33/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8618 - loss: 0.3326 - val_accuracy: 0.8610 - val_loss: 0.3379
# Epoch 34/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8634 - loss: 0.3354 - val_accuracy: 0.8580 - val_loss: 0.3388
# Epoch 35/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8655 - loss: 0.3326 - val_accuracy: 0.8635 - val_loss: 0.3360
# Epoch 36/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8659 - loss: 0.3268 - val_accuracy: 0.8580 - val_loss: 0.3368
# Epoch 37/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8658 - loss: 0.3298 - val_accuracy: 0.8620 - val_loss: 0.3372
# Epoch 38/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8664 - loss: 0.3335 - val_accuracy: 0.8610 - val_loss: 0.3382
# Epoch 39/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8631 - loss: 0.3302 - val_accuracy: 0.8570 - val_loss: 0.3385
# Epoch 40/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8652 - loss: 0.3292 - val_accuracy: 0.8580 - val_loss: 0.3372
# Epoch 41/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8669 - loss: 0.3252 - val_accuracy: 0.8635 - val_loss: 0.3379
# Epoch 42/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8673 - loss: 0.3262 - val_accuracy: 0.8575 - val_loss: 0.3401
# Epoch 43/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8654 - loss: 0.3257 - val_accuracy: 0.8600 - val_loss: 0.3359
# Epoch 44/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8666 - loss: 0.3237 - val_accuracy: 0.8585 - val_loss: 0.3365
# Epoch 45/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8674 - loss: 0.3245 - val_accuracy: 0.8555 - val_loss: 0.3385
# Epoch 46/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8696 - loss: 0.3249 - val_accuracy: 0.8565 - val_loss: 0.3394
# Epoch 47/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8700 - loss: 0.3234 - val_accuracy: 0.8565 - val_loss: 0.3391
# Epoch 48/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8689 - loss: 0.3219 - val_accuracy: 0.8590 - val_loss: 0.3396
# Epoch 49/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8681 - loss: 0.3288 - val_accuracy: 0.8580 - val_loss: 0.3376
# Epoch 50/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8692 - loss: 0.3227 - val_accuracy: 0.8590 - val_loss: 0.3378
# Epoch 51/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8687 - loss: 0.3246 - val_accuracy: 0.8605 - val_loss: 0.3370
# Epoch 52/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8654 - loss: 0.3261 - val_accuracy: 0.8610 - val_loss: 0.3353
# Epoch 53/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8715 - loss: 0.3226 - val_accuracy: 0.8585 - val_loss: 0.3386
# Epoch 54/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8701 - loss: 0.3224 - val_accuracy: 0.8565 - val_loss: 0.3395
# Epoch 55/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8681 - loss: 0.3197 - val_accuracy: 0.8600 - val_loss: 0.3374
# Epoch 56/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8679 - loss: 0.3222 - val_accuracy: 0.8555 - val_loss: 0.3415
# Epoch 57/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8691 - loss: 0.3212 - val_accuracy: 0.8595 - val_loss: 0.3384
# Epoch 58/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8699 - loss: 0.3178 - val_accuracy: 0.8605 - val_loss: 0.3363
# Epoch 59/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8692 - loss: 0.3184 - val_accuracy: 0.8565 - val_loss: 0.3399
# Epoch 60/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8716 - loss: 0.3190 - val_accuracy: 0.8560 - val_loss: 0.3377
# Epoch 61/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8687 - loss: 0.3177 - val_accuracy: 0.8590 - val_loss: 0.3359
# Epoch 62/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8702 - loss: 0.3166 - val_accuracy: 0.8575 - val_loss: 0.3382
# Epoch 63/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8696 - loss: 0.3212 - val_accuracy: 0.8585 - val_loss: 0.3403
# Epoch 64/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8724 - loss: 0.3141 - val_accuracy: 0.8615 - val_loss: 0.3397
# Epoch 65/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8710 - loss: 0.3203 - val_accuracy: 0.8615 - val_loss: 0.3407
# Epoch 66/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8709 - loss: 0.3179 - val_accuracy: 0.8565 - val_loss: 0.3409
# Epoch 67/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8725 - loss: 0.3141 - val_accuracy: 0.8590 - val_loss: 0.3389
# Epoch 68/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8702 - loss: 0.3141 - val_accuracy: 0.8590 - val_loss: 0.3412
# Epoch 69/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8726 - loss: 0.3156 - val_accuracy: 0.8575 - val_loss: 0.3413
# Epoch 70/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8727 - loss: 0.3174 - val_accuracy: 0.8585 - val_loss: 0.3399
# Epoch 71/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8700 - loss: 0.3169 - val_accuracy: 0.8585 - val_loss: 0.3400
# Epoch 72/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8731 - loss: 0.3137 - val_accuracy: 0.8555 - val_loss: 0.3421
# Epoch 73/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8720 - loss: 0.3154 - val_accuracy: 0.8555 - val_loss: 0.3413
# Epoch 74/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.3112 - val_accuracy: 0.8565 - val_loss: 0.3408
# Epoch 75/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8741 - loss: 0.3137 - val_accuracy: 0.8520 - val_loss: 0.3443
# Epoch 76/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8720 - loss: 0.3114 - val_accuracy: 0.8575 - val_loss: 0.3415
# Epoch 77/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8717 - loss: 0.3139 - val_accuracy: 0.8590 - val_loss: 0.3409
# Epoch 78/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8740 - loss: 0.3114 - val_accuracy: 0.8520 - val_loss: 0.3441
# Epoch 79/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8709 - loss: 0.3145 - val_accuracy: 0.8575 - val_loss: 0.3413
# Epoch 80/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8735 - loss: 0.3112 - val_accuracy: 0.8545 - val_loss: 0.3445
# Epoch 81/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8755 - loss: 0.3111 - val_accuracy: 0.8575 - val_loss: 0.3429
# Epoch 82/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8714 - loss: 0.3114 - val_accuracy: 0.8605 - val_loss: 0.3404
# Epoch 83/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8752 - loss: 0.3108 - val_accuracy: 0.8620 - val_loss: 0.3396
# Epoch 84/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8731 - loss: 0.3096 - val_accuracy: 0.8570 - val_loss: 0.3418
# Epoch 85/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8754 - loss: 0.3121 - val_accuracy: 0.8580 - val_loss: 0.3405
# Epoch 86/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.3117 - val_accuracy: 0.8565 - val_loss: 0.3396
# Epoch 87/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.3054 - val_accuracy: 0.8585 - val_loss: 0.3435
# Epoch 88/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8726 - loss: 0.3109 - val_accuracy: 0.8585 - val_loss: 0.3424
# Epoch 89/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8731 - loss: 0.3113 - val_accuracy: 0.8545 - val_loss: 0.3439
# Epoch 90/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.3064 - val_accuracy: 0.8615 - val_loss: 0.3421
# Epoch 91/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8746 - loss: 0.3051 - val_accuracy: 0.8550 - val_loss: 0.3447
# Epoch 92/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8736 - loss: 0.3089 - val_accuracy: 0.8600 - val_loss: 0.3420
# Epoch 93/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8788 - loss: 0.3036 - val_accuracy: 0.8555 - val_loss: 0.3418
# Epoch 94/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8771 - loss: 0.3047 - val_accuracy: 0.8550 - val_loss: 0.3442
# Epoch 95/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8760 - loss: 0.3044 - val_accuracy: 0.8565 - val_loss: 0.3429
# Epoch 96/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8735 - loss: 0.3060 - val_accuracy: 0.8595 - val_loss: 0.3439
# Epoch 97/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8756 - loss: 0.3067 - val_accuracy: 0.8600 - val_loss: 0.3441
# Epoch 98/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8750 - loss: 0.3047 - val_accuracy: 0.8605 - val_loss: 0.3393
# Epoch 99/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8759 - loss: 0.3061 - val_accuracy: 0.8575 - val_loss: 0.3413
# Epoch 100/100
# 80/80 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8770 - loss: 0.3063 - val_accuracy: 0.8575 - val_loss: 0.3455
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# Confusion Matrix (Improved Model):
# [[1510   85]
#  [ 200  205]]
# Accuracy (Improved Model): 0.8575

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, ELU
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from keras.utils import plot_model
import matplotlib.pyplot as plt

best_model = Sequential()

best_model.add(Dense(units=128, kernel_initializer='random_normal', input_dim=x_train.shape[1]))
best_model.add(ELU())
best_model.add(Dropout(rate=0.3))

best_model.add(Dense(units=64, kernel_initializer='random_normal'))
best_model.add(ELU())
best_model.add(Dropout(rate=0.3))

best_model.add(Dense(units=32, kernel_initializer='random_normal'))
best_model.add(ELU())
best_model.add(Dropout(rate=0.2))

best_model.add(Dense(units=1, kernel_initializer='random_normal', activation='sigmoid'))
best_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

print("--- Training the Best ANN Model ---")
history_best_model = best_model.fit(x_train, y_train, batch_size=8, epochs=50, verbose=1, validation_data=(x_test, y_test))
# Out:
# --- Training the Best ANN Model ---
# Epoch 1/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.8044 - loss: 0.4562 - val_accuracy: 0.8145 - val_loss: 0.4165
# Epoch 2/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8259 - loss: 0.4194 - val_accuracy: 0.8475 - val_loss: 0.3841
# Epoch 3/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8335 - loss: 0.3936 - val_accuracy: 0.8585 - val_loss: 0.3566
# Epoch 4/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8413 - loss: 0.3783 - val_accuracy: 0.8630 - val_loss: 0.3494
# Epoch 5/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8454 - loss: 0.3751 - val_accuracy: 0.8585 - val_loss: 0.3435
# Epoch 6/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8464 - loss: 0.3712 - val_accuracy: 0.8585 - val_loss: 0.3511
# Epoch 7/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8496 - loss: 0.3694 - val_accuracy: 0.8595 - val_loss: 0.3439
# Epoch 8/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8509 - loss: 0.3687 - val_accuracy: 0.8595 - val_loss: 0.3503
# Epoch 9/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8521 - loss: 0.3648 - val_accuracy: 0.8640 - val_loss: 0.3437
# Epoch 10/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8484 - loss: 0.3670 - val_accuracy: 0.8610 - val_loss: 0.3449
# Epoch 11/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8522 - loss: 0.3620 - val_accuracy: 0.8500 - val_loss: 0.3518
# Epoch 12/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8522 - loss: 0.3612 - val_accuracy: 0.8595 - val_loss: 0.3448
# Epoch 13/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8503 - loss: 0.3642 - val_accuracy: 0.8600 - val_loss: 0.3398
# Epoch 14/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8482 - loss: 0.3637 - val_accuracy: 0.8580 - val_loss: 0.3446
# Epoch 15/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8531 - loss: 0.3610 - val_accuracy: 0.8545 - val_loss: 0.3434
# Epoch 16/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8505 - loss: 0.3634 - val_accuracy: 0.8520 - val_loss: 0.3529
# Epoch 17/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8519 - loss: 0.3620 - val_accuracy: 0.8615 - val_loss: 0.3442
# Epoch 18/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8544 - loss: 0.3583 - val_accuracy: 0.8565 - val_loss: 0.3514
# Epoch 19/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8544 - loss: 0.3586 - val_accuracy: 0.8625 - val_loss: 0.3399
# Epoch 20/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8529 - loss: 0.3593 - val_accuracy: 0.8610 - val_loss: 0.3417
# Epoch 21/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8531 - loss: 0.3558 - val_accuracy: 0.8650 - val_loss: 0.3408
# Epoch 22/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8533 - loss: 0.3551 - val_accuracy: 0.8630 - val_loss: 0.3386
# Epoch 23/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8551 - loss: 0.3523 - val_accuracy: 0.8625 - val_loss: 0.3427
# Epoch 24/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8551 - loss: 0.3541 - val_accuracy: 0.8580 - val_loss: 0.3410
# Epoch 25/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8574 - loss: 0.3516 - val_accuracy: 0.8605 - val_loss: 0.3361
# Epoch 26/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8554 - loss: 0.3546 - val_accuracy: 0.8585 - val_loss: 0.3383
# Epoch 27/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8535 - loss: 0.3536 - val_accuracy: 0.8605 - val_loss: 0.3360
# Epoch 28/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8568 - loss: 0.3483 - val_accuracy: 0.8655 - val_loss: 0.3358
# Epoch 29/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8564 - loss: 0.3506 - val_accuracy: 0.8605 - val_loss: 0.3408
# Epoch 30/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8540 - loss: 0.3522 - val_accuracy: 0.8650 - val_loss: 0.3319
# Epoch 31/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8576 - loss: 0.3525 - val_accuracy: 0.8640 - val_loss: 0.3342
# Epoch 32/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8528 - loss: 0.3521 - val_accuracy: 0.8595 - val_loss: 0.3427
# Epoch 33/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8549 - loss: 0.3487 - val_accuracy: 0.8640 - val_loss: 0.3345
# Epoch 34/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8569 - loss: 0.3497 - val_accuracy: 0.8645 - val_loss: 0.3338
# Epoch 35/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8581 - loss: 0.3491 - val_accuracy: 0.8610 - val_loss: 0.3313
# Epoch 36/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8560 - loss: 0.3484 - val_accuracy: 0.8625 - val_loss: 0.3346
# Epoch 37/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8562 - loss: 0.3521 - val_accuracy: 0.8625 - val_loss: 0.3336
# Epoch 38/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8577 - loss: 0.3483 - val_accuracy: 0.8615 - val_loss: 0.3351
# Epoch 39/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8575 - loss: 0.3461 - val_accuracy: 0.8595 - val_loss: 0.3390
# Epoch 40/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.8597 - loss: 0.3449 - val_accuracy: 0.8635 - val_loss: 0.3376
# Epoch 41/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8554 - loss: 0.3495 - val_accuracy: 0.8610 - val_loss: 0.3320
# Epoch 42/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8568 - loss: 0.3506 - val_accuracy: 0.8630 - val_loss: 0.3355
# Epoch 43/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8594 - loss: 0.3469 - val_accuracy: 0.8610 - val_loss: 0.3406
# Epoch 44/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8587 - loss: 0.3442 - val_accuracy: 0.8610 - val_loss: 0.3352
# Epoch 45/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8602 - loss: 0.3464 - val_accuracy: 0.8650 - val_loss: 0.3365
# Epoch 46/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8575 - loss: 0.3441 - val_accuracy: 0.8635 - val_loss: 0.3313
# Epoch 47/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8600 - loss: 0.3446 - val_accuracy: 0.8625 - val_loss: 0.3373
# Epoch 48/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8581 - loss: 0.3486 - val_accuracy: 0.8580 - val_loss: 0.3387
# Epoch 49/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8586 - loss: 0.3437 - val_accuracy: 0.8670 - val_loss: 0.3377
# Epoch 50/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8585 - loss: 0.3441 - val_accuracy: 0.8660 - val_loss: 0.3327

# %%
y_pred_best_model = (best_model.predict(x_test) > 0.5)

accuracy_best_model = accuracy_score(y_test, y_pred_best_model)
cm_best_model = confusion_matrix(y_test, y_pred_best_model)
classification_rep_best_model = classification_report(y_test, y_pred_best_model)

print(f"\n--- Best Model Evaluation ---")
print(f"Accuracy (Best Model): {accuracy_best_model:.4f}")
print(f"\nConfusion Matrix (Best Model):\n{cm_best_model}")
print(f"\nClassification Report (Best Model):\n{classification_rep_best_model}")
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# --- Best Model Evaluation ---
# Accuracy (Best Model): 0.8660
#
# Confusion Matrix (Best Model):
# [[1530   65]
#  [ 203  202]]
#
# Classification Report (Best Model):
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1595
#            1       0.76      0.50      0.60       405
#
#     accuracy                           0.87      2000
#    macro avg       0.82      0.73      0.76      2000
# weighted avg       0.86      0.87      0.86      2000

# %%
print("\n--- Best Model Architecture ---")
best_model.summary()
plot_model(best_model, to_file='best_model_architecture.png', show_shapes=True, show_layer_names=True)
print("Model architecture saved to best_model_architecture.png")

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history_best_model.history['accuracy'], label='Train Accuracy')
plt.plot(history_best_model.history['val_accuracy'], label='Validation Accuracy')
plt.title('Best Model Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history_best_model.history['loss'], label='Train Loss')
plt.plot(history_best_model.history['val_loss'], label='Validation Loss')
plt.title('Best Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# --- Best Model Architecture ---
# Model: "sequential_36"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_110 (Dense)               │ (None, 128)            │         1,408 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_2 (ELU)                     │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_111 (Dense)               │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_3 (ELU)                     │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_112 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ elu_4 (ELU)                     │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_113 (Dense)               │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,333 (138.02 KB)
#  Trainable params: 11,777 (46.00 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 23,556 (92.02 KB)
# You must install pydot (`pip install pydot`) for `plot_model` to work.
# Model architecture saved to best_model_architecture.png
